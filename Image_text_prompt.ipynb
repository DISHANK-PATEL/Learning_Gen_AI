# %%
# !pip install -q -U google-generativeai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.4/725.4 kB 6.2 MB/s eta 0:00:00

# %%
import pathlib
import textwrap
import google.generativeai as genai
from google.colab import userdata
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('.', ' ** ')

    indented_text = textwrap.indent(text, '>', predicate=lambda _: True)
    return Markdown(indented_text)

# %%
import os
os.environ['GOOGLE_API_KEY']="AIzaSyDRC0J9w-SknMrM4Hk3xGpeNFkypFE2Rrg"

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
model=genai.GenerativeModel('gemini-pro')

# %%
response=model.generate_content("Give me info of jaundice ",stream=True)

# %%
for chunk in response:
   print(chunk.text)
   print("_"*80)
# Out:
# **Jaundice**
#
# **Definition:**
# Jaundice is a medical condition characterized
# ________________________________________________________________________________
#  by a yellow discoloration of the skin, mucous membranes, and eyes caused by elevated levels of bilirubin in the body.
#
# **Causes:**
# * **Liver
# ________________________________________________________________________________
#  disease:** Cirrhosis, hepatitis, liver cancer, biliary obstruction
# * **Blood disorders:** Hemolytic anemia, sickle cell disease
# * **Pancreatic disease:** Pancreatitis, pancreatic cancer
# * **Certain medications:** Antibiotics, steroids
# * **Gilbert's syndrome:** A harmless genetic condition that leads to mild jaundice
# ________________________________________________________________________________
#
# * **Dubin-Johnson syndrome:** A rare genetic condition that affects bile transport
#
# **Pathophysiology:**
# Bilirubin is a yellow pigment produced by the breakdown of old red blood cells. Normally, bilirubin is processed by the liver and excreted into the bile, which is then passed into the intestines and excreted with stool. When there is a problem in any of these steps, bilirubin can accumulate in the body and cause jaundice.
#
# **Symptoms:**
# * Yellow discoloration of the skin, whites of the eyes, and mucous membranes
# * Darkened urine
# * Light-colored stools
# * Fatigue
# * Nausea and vomiting
# ________________________________________________________________________________
#
# * Abdominal pain or discomfort
# * Itching
#
# **Diagnosis:**
# * Physical examination
# * Blood tests to measure bilirubin levels
# * Liver function tests
# * Imaging studies (e.g., ultrasound, CT scan) to determine the underlying cause
#
# **Treatment:**
# Treatment depends on the underlying cause of the jaundice. Options include:
# * Medications to reduce bilirubin (cholestyramine)
# * Surgery to relieve biliary obstruction
# * Liver transplant in severe liver disease
# * Treatment of underlying blood or pancreatic disorders
#
# **Complications:**
# * Liver failure
# * Permanent damage to the brain (kernicterus) in newborns
# * Increased risk of gallstones
#
# **Prevention:**
# * Vaccinations against hepatitis A and B
# * Prudent use of medications that can cause jaundice
# * Management of underlying medical conditions (e.g., sickle cell disease)
# ________________________________________________________________________________

# %%
# !curl -o image.jpg "https://imgs.search.brave.com/pJulsikYgFQBIc5f_QKcaJ9i1rwa1hcO5BYCf3o3-Ls/rs:fit:860:0:0:0/g:ce/aHR0cHM6Ly9pbWcu/aW5kaWFmb3J1bXMu/Y29tL21lZGlhLzcy/MHgwLzU3LzQ1NTYt/dmlyYXQta29obGkt/YW51c2hrYS1zaGFy/bWEuanBn"
import PIL.Image
img=PIL.Image.open('image.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1112x643>

# %%
model=genai.GenerativeModel('gemini-1.5-flash')

# %%
import requests
from PIL import Image
import io
image_url = "https://images.drlogy.com/assets/uploads/lab/image/cbc-absolute-count-test-report-format-example-sample-template-drlogy-lab-report.webp"
response = requests.get(image_url, stream=True)
image = Image.open(io.BytesIO(response.content))
text_prompt = "Tell me about the image wrt to health"
response = model.generate_content([image, text_prompt], stream=True)
for chunk in response:
    print(chunk.text)
    print("_"*80)
# Out:
# This
# ________________________________________________________________________________
#  is a lab report for a complete blood count (CBC) test. It shows
# ________________________________________________________________________________
#  the results of a blood test taken by Yash M. Patel, a 2
# ________________________________________________________________________________
# 1-year-old male. The report includes information on the patient's hemoglobin levels, red blood cell count, white blood cell count, and platelet count
# ________________________________________________________________________________
# . The report also includes the reference range for each value and the unit of measurement. The results of the test are considered to be normal.
# ________________________________________________________________________________
